# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso,LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC,SVR
from tqdm.notebook import tqdm as tqdm
from sklearn import decomposition
import seaborn as sns
from sklearn.manifold import TSNE, LocallyLinearEmbedding, MDS
from pandas.plotting import scatter_matrix
from sklearn import datasets
plt.style.use("bmh")

# %% [markdown]
# # Students Performance Analysis
#
# ### Q.1
#
# Read the attached "students.csv" file to a DataFrame.

# %%
data = pd.read_csv("students.csv")
data.head()
# Out:
#   gender NationalITy     StageID GradeID SectionID Topic Semester Relation  \
# 0      M          KW  lowerlevel    G-04         A    IT        F   Father
# 1      M          KW  lowerlevel    G-04         A    IT        F   Father
# 2      M          KW  lowerlevel    G-04         A    IT        F   Father
# 3      M          KW  lowerlevel    G-04         A    IT        F   Father
# 4      M          KW  lowerlevel    G-04         A    IT        F   Father
#
#    raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0           15                16                  2          20
# 1           20                20                  3          25
# 2           10                 7                  0          30
# 3           30                25                  5          35
# 4           40                50                 12          50
#
#   ParentAnsweringSurvey ParentschoolSatisfaction StudentAbsenceDays Class
# 0                   Yes                     Good            Under-7     M
# 1                   Yes                     Good            Under-7     M
# 2                    No                      Bad            Above-7     L
# 3                    No                      Bad            Above-7     L
# 4                    No                      Bad            Above-7     M

# %% [markdown]
# ### Q.2
#
# Print the features name and type.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   StageID                   480 non-null    object
#  3   GradeID                   480 non-null    object
#  4   SectionID                 480 non-null    object
#  5   Topic                     480 non-null    object
#  6   Semester                  480 non-null    object
#  7   Relation                  480 non-null    object
#  8   raisedhands               480 non-null    int64
#  9   VisITedResources          480 non-null    int64
#  10  AnnouncementsView         480 non-null    int64
#  11  Discussion                480 non-null    int64
#  12  ParentAnsweringSurvey     480 non-null    object
#  13  ParentschoolSatisfaction  480 non-null    object
#  14  StudentAbsenceDays        480 non-null    object
#  15  Class                     480 non-null    object
# dtypes: int64(4), object(12)
# memory usage: 60.1+ KB

# %% [markdown]
# ### Q.3
#
# #### 3.1
#
# Perform feature encoding on the categorical features. <br/>
# For each categorical feature, create LabelEncoder and transform its values.

# %%
le_map = {}
categorical_features = data.select_dtypes(include=["object"]).columns
for cat_feature in categorical_features:
    le_map[cat_feature] = LabelEncoder()
    data[cat_feature] = le_map[cat_feature].fit_transform(data[cat_feature])

# %%
data.head()
# Out:
#    gender  NationalITy  StageID  GradeID  SectionID  Topic  Semester  \
# 0       1            4        2        1          0      7         0
# 1       1            4        2        1          0      7         0
# 2       1            4        2        1          0      7         0
# 3       1            4        2        1          0      7         0
# 4       1            4        2        1          0      7         0
#
#    Relation  raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0         0           15                16                  2          20
# 1         0           20                20                  3          25
# 2         0           10                 7                  0          30
# 3         0           30                25                  5          35
# 4         0           40                50                 12          50
#
#    ParentAnsweringSurvey  ParentschoolSatisfaction  StudentAbsenceDays  Class
# 0                      1                         1                   1      2
# 1                      1                         1                   1      2
# 2                      0                         0                   0      1
# 3                      0                         0                   0      1
# 4                      0                         0                   0      2

# %% [markdown]
# #### 3.2
#
# Print the mapping values of "NationalITy" feature.

# %%
le_map["NationalITy"].classes_
# Out:
# array(['Egypt', 'Iran', 'Iraq', 'Jordan', 'KW', 'Lybia', 'Morocco',
#        'Palestine', 'SaudiArabia', 'Syria', 'Tunis', 'USA', 'lebanon',
#        'venzuela'], dtype=object)

# %%
pd.Series(le_map["NationalITy"].classes_)
# Out:
# 0           Egypt
# 1            Iran
# 2            Iraq
# 3          Jordan
# 4              KW
# 5           Lybia
# 6         Morocco
# 7       Palestine
# 8     SaudiArabia
# 9           Syria
# 10          Tunis
# 11            USA
# 12        lebanon
# 13       venzuela
# dtype: object

# %% [markdown]
# ### Q.4
#
# #### 4.1
# Use the method 'evaluate_RF' we have implemented in ensemble learning practice and evaluate it on the students dataset.

# %%
def evaluate_RF(X, y, n_estimators, max_depth=[2,8,16,32]):
    res = {}
    for md in max_depth:
        rf = RandomForestClassifier(n_estimators=n_estimators, max_depth=md, random_state=1)
        res['rf_'+str(md)] = np.mean(cross_val_score(rf,X,y,cv=3,scoring="accuracy"))
    return res

# %%
X = data.drop(columns=["Class"])
y = data["Class"].copy()

# %%
evaluate_RF(X, y, 200)
# Out:
# {'rf_2': 0.65, 'rf_8': 0.69375, 'rf_16': 0.68125, 'rf_32': 0.68125}

# %% [markdown]
# #### 4.2
#
# Use the hyperparameters discovered in 4.1 and display the importance of each feature.

# %%
RF = RandomForestClassifier(n_estimators=200, max_depth=8, random_state=1)
RF.fit(X,y)
importances = pd.DataFrame({
    "Feature": X.columns,
    "Importance": RF.feature_importances_ * 100
})
importances = importances.sort_values("Importance", ascending=False)
importances
# Out:
#                      Feature  Importance
# 9           VisITedResources   18.788367
# 8                raisedhands   16.656039
# 14        StudentAbsenceDays   13.859538
# 10         AnnouncementsView   12.040713
# 11                Discussion    8.735933
# 7                   Relation    4.901487
# 5                      Topic    4.285209
# 1                NationalITy    4.035904
# 12     ParentAnsweringSurvey    3.930613
# 3                    GradeID    3.382052
# 13  ParentschoolSatisfaction    2.583271
# 0                     gender    2.374376
# 4                  SectionID    1.850338
# 2                    StageID    1.587522
# 6                   Semester    0.988638

# %% [markdown]
# #### 4.3
#
# Drop the least important feature.

# %%
data.drop(columns=["Semester"], inplace=True)
data.head()
# Out:
#    gender  NationalITy  StageID  GradeID  SectionID  Topic  Relation  \
# 0       1            4        2        1          0      7         0
# 1       1            4        2        1          0      7         0
# 2       1            4        2        1          0      7         0
# 3       1            4        2        1          0      7         0
# 4       1            4        2        1          0      7         0
#
#    raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0           15                16                  2          20
# 1           20                20                  3          25
# 2           10                 7                  0          30
# 3           30                25                  5          35
# 4           40                50                 12          50
#
#    ParentAnsweringSurvey  ParentschoolSatisfaction  StudentAbsenceDays  Class
# 0                      1                         1                   1      2
# 1                      1                         1                   1      2
# 2                      0                         0                   0      1
# 3                      0                         0                   0      1
# 4                      0                         0                   0      2

# %% [markdown]
# #### 4.4
#
# Use <strong>Automated Feature Selection (AFS)</strong> based on GradientBoostingClassifier and find the most important features using the <strong>median</strong> threshold.

# %%
select = SelectFromModel(GradientBoostingClassifier(n_estimators=200, random_state=42), threshold="median")
select.fit(X, y)
mask = select.get_support()
result = pd.DataFrame({
    "Features": X.columns,
    "Selected": mask
})
result
# Out:
#                     Features  Selected
# 0                     gender     False
# 1                NationalITy     False
# 2                    StageID     False
# 3                    GradeID     False
# 4                  SectionID     False
# 5                      Topic      True
# 6                   Semester     False
# 7                   Relation      True
# 8                raisedhands      True
# 9           VisITedResources      True
# 10         AnnouncementsView      True
# 11                Discussion      True
# 12     ParentAnsweringSurvey      True
# 13  ParentschoolSatisfaction     False
# 14        StudentAbsenceDays      True

# %% [markdown]
# #### 4.5
#
# Create the "selected_features" list with features that satisfy "Selected = True".

# %%
selected_features = result[result["Selected"] == True]["Features"].values
selected_features
# Out:
# array(['Topic', 'Relation', 'raisedhands', 'VisITedResources',
#        'AnnouncementsView', 'Discussion', 'ParentAnsweringSurvey',
#        'StudentAbsenceDays'], dtype=object)

# %% [markdown]
# ### Q.5
#
# #### 5.1
#
# Create new DataFrame using the selected features, and split to (X,y).

# %%
new_df = data[selected_features].copy()
target = data["Class"].copy()
new_df
# Out:
#      Topic  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        7         0           15                16                  2
# 1        7         0           20                20                  3
# 2        7         0           10                 7                  0
# 3        7         0           30                25                  5
# 4        7         0           40                50                 12
# ..     ...       ...          ...               ...                ...
# 475      2         0            5                 4                  5
# 476      5         0           50                77                 14
# 477      5         0           55                74                 25
# 478      6         0           30                17                 14
# 479      6         0           35                14                 23
#
#      Discussion  ParentAnsweringSurvey  StudentAbsenceDays
# 0            20                      1                   1
# 1            25                      1                   1
# 2            30                      0                   0
# 3            35                      0                   0
# 4            50                      0                   0
# ..          ...                    ...                 ...
# 475           8                      0                   0
# 476          28                      0                   1
# 477          29                      0                   1
# 478          57                      0                   0
# 479          62                      0                   0
#
# [480 rows x 8 columns]

# %% [markdown]
# #### 5.2
#
# Implement the function  `search_for_hyperparameters(X, y, model_name, model, param_grid)`
#
# That gets as input:
# * X - dataset
# * y - target variable
# * model_name - string
# * model - Object
# * param_grid
#
# and perform GridSearchCV

# %%
def search_for_hyperparameters(X, y, model_name, model, param_grid):
    pipe = Pipeline([(model_name, model)])
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=5)
    grid.fit(X, y)
    print("Test set score: {:.2f}".format(grid.score(new_df, target)))
    print("Best parameters: {}".format(grid.best_params_))

# %% [markdown]
# #### 5.3
#
# Test your method on: AdaBoostClassifier, RandomForestClassifier, SVC

# %%
ab_grid = {
    "ab__learning_rate": [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]
}
search_for_hyperparameters(new_df, target, "ab", AdaBoostClassifier(), ab_grid)
# Out:
# Test set score: 0.73
# Best parameters: {'ab__learning_rate': 0.5}

# %%
rf_grid = {
    "rf__n_estimators": [50, 100, 150, 200, 250],
    "rf__max_depth": [2,4,8,16,32]
}
search_for_hyperparameters(new_df, target, "rf", RandomForestClassifier(),rf_grid)
# Out:
# Test set score: 0.84
# Best parameters: {'rf__max_depth': 4, 'rf__n_estimators': 100}

# %%
svm_grid = {
    'svm__C': [0.001, 0.01, 0.1, 1, 10, 100],
    'svm__gamma': [0.001, 0.01, 0.1, 1, 10, 100]
}
search_for_hyperparameters(new_df, target, "svm", SVC(), svm_grid)
# Out:
# Test set score: 0.76
# Best parameters: {'svm__C': 1, 'svm__gamma': 0.001}

# %% [markdown]
# ### Q.6
#
# Use the new dataset and display the plots of PCA, tSNE, and MDS.

# %%
def plot_PCA(data, labels):
    pca = decomposition.PCA(n_components = 2)
    pca_data = pca.fit_transform(data)
    pca_data = np.vstack((pca_data.T, labels)).T
    df = pd.DataFrame(data=pca_data, columns=("dim1", "dim2", "Label"))
    sns.FacetGrid(df, hue="Label", height=6).map(plt.scatter, 'dim1', 'dim2').add_legend()
    plt.title("PCA")
    plt.show()
    
def plot_tSNE(data, labels, perplexity=[5,20,30,50]):
    kl_divergence_iris = []
    fig, ax = plt.subplots(1, 4, figsize=(40, 8))
    for idx, p in enumerate(perplexity):
        tsne = TSNE(n_components=2, random_state=0, perplexity=p)
        tsne_data = tsne.fit_transform(data)
        kl_divergence_iris.append(tsne.kl_divergence_)
        tsne_data = np.vstack((tsne_data.T, labels)).T
        df = pd.DataFrame(data=tsne_data, columns=("dim1", "dim2", "Label"))
        sns.scatterplot(x=df['dim1'], y=df['dim2'], hue=df["Label"], ax=ax[idx], s=100,palette='colorblind').set_title("t-SNE with perplexity="+str(p))
    plt.show()
    
def plot_MDS(data, labels):
    mds = MDS(n_components=2)
    mds_data = mds.fit_transform(data)
    mds_data_iris = np.vstack((mds_data.T, labels)).T
    df = pd.DataFrame(data=mds_data_iris, columns=("dim1", "dim2", "Label"))
    sns.FacetGrid(df, hue="Label", height=6).map(plt.scatter, 'dim1', 'dim2').add_legend()
    plt.title("MDS with final stress=" + str(mds.stress_))
    plt.show()

# %%
plot_PCA(new_df,target)

# %%
le_map["Class"].classes_
# Out:
# array(['H', 'L', 'M'], dtype=object)

# %%
plot_tSNE(new_df,target)

# %%
plot_MDS(new_df,target)

# %% [markdown]
# ### Q.7
#
# Choose one model (based on the result of this practice) and evaulate it on the students dataset. <br/>
#
# Compare your result based on cross-validation-score using cv=5 and cv=10.

# %%
rf = RandomForestClassifier(n_estimators=200, max_depth=4)
rf.fit(new_df, target)
cross_val_score(rf, new_df, target, cv=5)
# Out:
# array([0.6875    , 0.6875    , 0.69791667, 0.78125   , 0.69791667])

# %%
cross_val_score(rf, new_df, target).mean()
# Out:
# 0.7020833333333334

# %%
cross_val_score(rf, new_df, target, cv=10)
# Out:
# array([0.75      , 0.70833333, 0.6875    , 0.66666667, 0.72916667,
#        0.70833333, 0.625     , 0.77083333, 0.77083333, 0.70833333])

# %%
cross_val_score(rf, new_df, target, cv=10).mean()
# Out:
# 0.7125

# %% [markdown]
# ### Q.8
#
# Build a procedure that allow you to predict future data based on your model.

# %%
new_df.head()
# Out:
#    Topic  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0      7         0           15                16                  2
# 1      7         0           20                20                  3
# 2      7         0           10                 7                  0
# 3      7         0           30                25                  5
# 4      7         0           40                50                 12
#
#    Discussion  ParentAnsweringSurvey  StudentAbsenceDays
# 0          20                      1                   1
# 1          25                      1                   1
# 2          30                      0                   0
# 3          35                      0                   0
# 4          50                      0                   0

# %%
def predict_student_performance(le_map, model, topic, relation, hands, resources, anno, discussion, parents, absence):
    to_predict = [
        le_map["Topic"].transform([topic])[0], 
        le_map["Relation"].transform([relation])[0],
        hands,
        resources,
        anno,
        discussion,
        le_map["ParentAnsweringSurvey"].transform([parents])[0],
        le_map["StudentAbsenceDays"].transform([absence])[0],
    ]
    predicted_value = model.predict([to_predict])[0]
    return le_map["Class"].inverse_transform([predicted_value])

# %%
predict_student_performance(le_map, rf, "Geology", "Father", 17, 22, 3, 45, "Yes", "Above-7")
# Out:
# array(['L'], dtype=object)

# %%
predict_student_performance(le_map, rf, "Chemistry", "Mum", 50, 40, 1, 30, "Yes", "Above-7")
# Out:
# array(['M'], dtype=object)

# %%
predict_student_performance(le_map, rf, "Math", "Mum", 120, 100, 5, 100, "Yes", "Under-7")
# Out:
# array(['H'], dtype=object)
